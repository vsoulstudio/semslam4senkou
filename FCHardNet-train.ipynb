# %% [markdown]
# 挂载google云盘/Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# 下载代码安装依赖，下载数据集并解压/Download the source code & Install the dependent libraries & Unzip the dataset

# %%
import os
os.chdir('/content/')
# !git clone https://github.com/vsoulstudio/FCHardNet-self.git
# !pip install -r /content/FCHardNet-self/requirements3.txt 
# !unzip /content/gdrive/MyDrive/colab/VOCdevkit.zip

# %% [markdown]
# 移动到google云盘目录，进行模型训练并保存/Change the loot to the Google Drive & Run the training program

# %%
import os
os.chdir('/content/gdrive/MyDrive/')
#%run /content/FCHardNet-self/train.py
#!CUDA_LAUNCH_BLOCKING=1
# !python /content/FCHardNet-self/train2.py

# %% [markdown]
# 特殊功能代码/special functional code

# %%
#代码更新
# !rm /content/FCHardNet-self/ -r -f 
import os
os.chdir('/content/')
# !git clone https://github.com/vsoulstudio/FCHardNet-self.git

# %%
#防短时间断连/avoid disconnected
'''
function ConnectButton(){
    console.log("Connect pushed"); 
    document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click() 
}
setInterval(ConnectButton,60000);
'''

# %%
#清理之前的文件/Clean up the exist file
# !rm /content/FCHardNet-self/ -r -f 
# !rm /content/VOCdevkit/ -r -f 
# !rm /content/gdrive/MyDrive/runs/ -r -f

# %% [markdown]
# 杂项&测试

# %%
# !pip show matplotlib
# !pip show numpy
# !pip show scipy
# !pip show torch
# !pip show torchvision
# !pip show tqdm
# !pip show pydensecrf
# !pip show protobuf
# !pip show tensorboardX

# %%
# !pip show numpy
# !pip show tensorboard

# %%
# !cp /content/gdrive/MyDrive/colab/FCHarDNet /content/ -r

# %%
# !nvidia-smi
# Out:
# Tue Jan  5 13:31:12 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.27.04    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8    28W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os
import sys
import subprocess
def get_linux_version():
        print("system version---- %s" % ", ".join(sys.version.split("\n")))
 
 
def get_cpu_info():
        processor_cnt = 0
        cpu_model = ""
        f_cpu_info = open("/proc/cpuinfo")
        try:
                for line in f_cpu_info:
                        if (line.find("processor") == 0):
                                processor_cnt += 1
                        elif (line.find("model name") == 0):
                                if (cpu_model == ""):
                                        cpu_model = line.split(":")[1].strip()
 
 
                print("cpu counts: %s, cpu model: %s" % (processor_cnt, cpu_model))
        finally:
                f_cpu_info.close()
 
 
def get_mem_info():
        mem_info = ""
        f_mem_info = open("/proc/meminfo")
        try:
                for line in f_mem_info:
                        if (line.find("MemTotal") == 0):
                                mem_info += line.strip()+ ", "
                        elif (line.find("SwapTotal") == 0):
                                mem_info += line.strip()
                                break
                print("mem_info---- {:s}".format(mem_info))
        finally:
                f_mem_info.close()
 
 
def get_disc_info():
        #disc_info = os.popen("df -h").read()
        #disc_info = subprocess.Popen("df -h", shell=True).communicate()[0]
        #print(disc_info)
        pipe = subprocess.Popen("df -h", stdout=subprocess.PIPE, shell=True)
        disc_info = pipe.stdout.read()
        print(disc_info)

get_cpu_info()
get_mem_info()
get_disc_info()
# Out:
# cpu counts: 2, cpu model: Intel(R) Xeon(R) CPU @ 2.30GHz
# mem_info---- MemTotal:       13333596 kB, SwapTotal:             0 kB
# b'Filesystem      Size  Used Avail Use% Mounted on\noverlay          69G   33G   37G  48% /\ntmpfs            64M     0   64M   0% /dev\ntmpfs           6.4G     0  6.4G   0% /sys/fs/cgroup\nshm             5.8G     0  5.8G   0% /dev/shm\n/dev/sda1        75G   34G   42G  45% /opt/bin\ntmpfs           6.4G   16K  6.4G   1% /var/colab\ntmpfs           6.4G     0  6.4G   0% /proc/acpi\ntmpfs           6.4G     0  6.4G   0% /proc/scsi\ntmpfs           6.4G     0  6.4G   0% /sys/firmware\n'
